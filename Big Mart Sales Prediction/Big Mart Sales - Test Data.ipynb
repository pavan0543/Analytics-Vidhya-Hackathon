# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['ggplot'])
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = "C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Analytics Vidhya\\Big Mart Sales Prediction\\Test data.csv"
df = pd.read_csv(file_path)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1

# %%
df.shape
# Out:
# (5681, 11)

# %%
df.size
# Out:
# 62491

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
num = df.select_dtypes(include = ["float64","int64"]).columns
cat = df.select_dtypes(include = ["object"]).columns

print(f"num : {num}")
print(f"cat : {cat}")

print(f"Count of num : {len(num)}")
print(f"Count of cat : {len(cat)}")
# Out:
# num : Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')
# cat : Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')
# Count of num : 4
# Count of cat : 7

# %%
#missing values

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
pd.get_dummies(df["Outlet_Size"])
# Out:
#        High  Medium  Small
# 0     False    True  False
# 1     False   False  False
# 2     False   False  False
# 3     False   False  False
# 4     False    True  False
# ...     ...     ...    ...
# 5676  False   False   True
# 5677  False    True  False
# 5678  False   False  False
# 5679  False   False  False
# 5680  False   False  False
#
# [5681 rows x 3 columns]

# %%
df["Outlet_Size"] = df["Outlet_Size"].fillna(df["Outlet_Size"].mode()[0])

# %%
df["Item_Weight"] = df["Item_Weight"].fillna(df["Item_Weight"].mean())

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
# missing values are removed 

df["Item_Type"].value_counts()
# Out:
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(22,8))
plt.bar(x = df["Item_Type"], height = df["Item_MRP"],color = "pink",)
plt.xlabel("Item Type")
plt.ylabel("Item MRP")
plt.show()

# %%
# Checking the outliers

# %%
plt.figure(figsize=(10,10))
for i ,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins=40)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i ,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
# so we can see the outliers in item visibility and item outlet sales

# %%
for column in num:
    p1 = round(np.percentile(df[column],25),2)
    p2 = round(np.percentile(df[column],50),2)
    p3 = round(np.percentile(df[column],75),2)
    
    print(f"{column} 25 percentile is : {p1}")
    print(f"{column} 50 percentile is : {p2}")
    print(f"{column} 75 percentile is : {p3}")
    
    print("----------------------------------------")
# Out:
# Item_Weight 25 percentile is : 9.2
# Item_Weight 50 percentile is : 12.7
# Item_Weight 75 percentile is : 15.85
# ----------------------------------------
# Item_Visibility 25 percentile is : 0.03
# Item_Visibility 50 percentile is : 0.05
# Item_Visibility 75 percentile is : 0.09
# ----------------------------------------
# Item_MRP 25 percentile is : 94.41
# Item_MRP 50 percentile is : 141.42
# Item_MRP 75 percentile is : 186.03
# ----------------------------------------
# Outlet_Establishment_Year 25 percentile is : 1987.0
# Outlet_Establishment_Year 50 percentile is : 1999.0
# Outlet_Establishment_Year 75 percentile is : 2004.0
# ----------------------------------------

# %%
#quantile

for column in num:
    q1 = round(np.quantile(df[column],.25),2)
    q2 = round(np.quantile(df[column],.50),2)
    q3 = round(np.quantile(df[column],.75),2)
    
    print(f"{column} 25 quantile is : {q1}")
    print(f"{column} 50 quantile is : {q2}")
    print(f"{column} 75 quantile is : {q3}")
    
    print("----------------------------------------")
# Out:
# Item_Weight 25 quantile is : 9.2
# Item_Weight 50 quantile is : 12.7
# Item_Weight 75 quantile is : 15.85
# ----------------------------------------
# Item_Visibility 25 quantile is : 0.03
# Item_Visibility 50 quantile is : 0.05
# Item_Visibility 75 quantile is : 0.09
# ----------------------------------------
# Item_MRP 25 quantile is : 94.41
# Item_MRP 50 quantile is : 141.42
# Item_MRP 75 quantile is : 186.03
# ----------------------------------------
# Outlet_Establishment_Year 25 quantile is : 1987.0
# Outlet_Establishment_Year 50 quantile is : 1999.0
# Outlet_Establishment_Year 75 quantile is : 2004.0
# ----------------------------------------

# %%
q1 = np.quantile(df["Item_Visibility"],.25)
q2 = np.quantile(df["Item_Visibility"],.50)
q3 = np.quantile(df["Item_Visibility"],.75)

Iqr = q3-q1

ub = q3+(1.5*Iqr)
lb = q1 - (1.5*Iqr)

cond1 = df["Item_Visibility"]>ub
cond2 = df["Item_Visibility"]<lb

outlier_df = df[cond1|cond2]

# %%
len(outlier_df)
# Out:
# 113

# %%
v1 = (len(outlier_df)/len(df))*100
v1
# Out:
# 1.9890864284456962

# %%
df["Item_Visibility"] = np.clip(df["Item_Visibility"],lb,ub)

# %%
#df["Item_Visibility"] = np.where(df["Item_Visibility"]>ub|df["Item_Visibility"]<lb,df["Item_Visibility"].median(),df["Item_Visibility"])

# %%
df[df["Item_Visibility"]<lb]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type]
# Index: []

# %%
plt.figure(figsize=(10,10))
for i ,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
len(df)
# Out:
# 5681

# %%
# Data Transformation skewed to Normal

# %%
from scipy.stats import skew

for i in num:
    print(df[i].skew())
# Out:
# 0.1428133167932425
# 0.8186307552373422
# 0.13618153880370937
# -0.39630647225627247

# %%
plt.figure(figsize=(10,10))
for i ,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins=40)
    
plt.show()

# %%
# apply log and sqrt transformation for positive skewed data
# apply reciprocal transformation for negative skewed data

# df["Item_Weight"] = np.sqrt(df["Item_Weight"])
# sns.distplot(df["Item_Weight"])
# plt.show()

# %%
plt.figure(figsize=(10,10))

for i,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.distplot(df[column])
    
plt.show()

# %%
df["Outlet_Establishment_Year"].skew()
# Out:
# -0.39630647225627247

# %%
df["Outlet_Establishment_Year"] = 1/df["Outlet_Establishment_Year"]
sns.displot(df["Outlet_Establishment_Year"],bins=40)
plt.show()

# %%
df["Outlet_Establishment_Year"].skew()
# Out:
# 0.40429042013662336

# %%
for i in num:
    print(df[i].skew())
# Out:
# 0.1428133167932425
# 0.8186307552373422
# 0.13618153880370937
# 0.40429042013662336

# %%
df["Item_Visibility"] = np.sqrt(df["Item_Visibility"])
plt.hist(df["Item_Visibility"],bins=40)
plt.show()

# %%
sns.distplot(df["Item_Visibility"],bins=40)
plt.show()

# %%
df["Item_Visibility"].skew()
# Out:
# -0.2397896527536095

# %%
for i in num:
    print(df[i].skew())
# Out:
# 0.1428133167932425
# -0.2397896527536095
# 0.13618153880370937
# 0.40429042013662336

# %%
# Bivariate and multivariate analysis

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.086976  Snack Foods
# 1           FDW14     8.300000              reg         0.196030        Dairy
# 2           NCN55    14.600000          Low Fat         0.315555       Others
# 3           FDQ58     7.315000          Low Fat         0.124050  Snack Foods
# 4           FDY38    12.695633          Regular         0.344383        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                   0.000500      Medium
# 1   87.3198            OUT017                   0.000498      Medium
# 2  241.7538            OUT010                   0.000501      Medium
# 3  155.0340            OUT017                   0.000498      Medium
# 4  234.2300            OUT027                   0.000504      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
cat
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
col1 = df["Outlet_Size"]
col2 = df["Outlet_Type"]
result1 = pd.crosstab(col1,col2)
result1
# Out:
# Outlet_Type  Grocery Store  Supermarket Type1  Supermarket Type2  \
# Outlet_Size
# High                     0                621                  0
# Medium                 370               1856                618
# Small                  352               1240                  0
#
# Outlet_Type  Supermarket Type3
# Outlet_Size
# High                         0
# Medium                     624
# Small                        0

# %%
result1.plot(kind = "bar")
# Out:
# <Axes: xlabel='Outlet_Size'>

# %%
col1 = df["Item_Type"]
col2 = df["Item_MRP"]

result2 = pd.crosstab(col1,col2)
result2
# Out:
# Item_MRP               31.9900   32.0558   32.0900   32.3900   32.4558   \
# Item_Type
# Baking Goods                  0         0         0         0         0
# Breads                        0         0         0         0         0
# Breakfast                     0         0         0         0         0
# Canned                        0         0         0         0         0
# Dairy                         0         0         0         0         0
# Frozen Foods                  0         0         0         0         0
# Fruits and Vegetables         0         0         0         0         0
# Hard Drinks                   0         0         0         0         0
# Health and Hygiene            0         0         0         0         0
# Household                     1         1         1         2         1
# Meat                          0         0         0         0         0
# Others                        0         0         0         0         0
# Seafood                       0         0         0         0         0
# Snack Foods                   0         0         0         0         0
# Soft Drinks                   0         0         0         1         0
# Starchy Foods                 0         0         0         0         0
#
# Item_MRP               32.5900   32.7558   32.8216   33.0558   33.0900   ...  \
# Item_Type                                                                ...
# Baking Goods                  0         0         0         0         0  ...
# Breads                        0         0         0         0         0  ...
# Breakfast                     0         0         0         0         0  ...
# Canned                        0         0         0         0         0  ...
# Dairy                         0         0         0         0         0  ...
# Frozen Foods                  0         0         0         0         0  ...
# Fruits and Vegetables         0         0         0         0         0  ...
# Hard Drinks                   0         0         0         0         0  ...
# Health and Hygiene            0         0         1         0         0  ...
# Household                     1         0         0         1         1  ...
# Meat                          0         0         0         0         0  ...
# Others                        0         0         0         0         0  ...
# Seafood                       0         0         0         0         0  ...
# Snack Foods                   0         1         0         1         0  ...
# Soft Drinks                   0         0         0         0         0  ...
# Starchy Foods                 0         0         0         0         0  ...
#
# Item_MRP               264.7910  264.9226  265.0568  265.0884  265.3226  \
# Item_Type
# Baking Goods                  0         0         0         0         0
# Breads                        0         0         0         0         0
# Breakfast                     0         0         0         0         0
# Canned                        0         0         0         0         0
# Dairy                         0         0         1         3         1
# Frozen Foods                  0         0         0         0         0
# Fruits and Vegetables         0         0         0         0         0
# Hard Drinks                   0         0         0         0         0
# Health and Hygiene            0         1         0         0         0
# Household                     1         0         0         0         0
# Meat                          0         0         0         0         0
# Others                        0         0         0         0         0
# Seafood                       0         0         0         0         0
# Snack Foods                   0         0         1         0         0
# Soft Drinks                   0         0         0         0         0
# Starchy Foods                 0         0         0         0         0
#
# Item_MRP               266.0884  266.2226  266.3226  266.4884  266.5884
# Item_Type
# Baking Goods                  0         0         0         0         0
# Breads                        0         0         0         0         0
# Breakfast                     0         0         0         0         0
# Canned                        1         0         0         1         1
# Dairy                         0         1         0         0         0
# Frozen Foods                  0         0         0         0         0
# Fruits and Vegetables         0         0         0         0         0
# Hard Drinks                   0         0         0         0         0
# Health and Hygiene            0         0         1         0         0
# Household                     0         0         0         0         0
# Meat                          0         0         0         0         0
# Others                        0         0         0         0         0
# Seafood                       0         0         0         0         0
# Snack Foods                   0         0         0         0         0
# Soft Drinks                   0         0         0         0         0
# Starchy Foods                 0         0         0         0         0
#
# [16 rows x 4402 columns]

# %%
pd.DataFrame(df["Item_MRP"].value_counts())
# Out:
#           count
# Item_MRP
# 57.0614       5
# 99.4700       4
# 141.2154      4
# 236.4564      4
# 186.8898      4
# ...         ...
# 156.3288      1
# 125.7388      1
# 42.6086       1
# 105.9964      1
# 79.7960       1
#
# [4402 rows x 1 columns]

# %%
#Conversion from cat to num

# %%
cat
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
num
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58    20.750000          Low Fat         0.086976
# 1              FDW14     8.300000              reg         0.196030
# 2              NCN55    14.600000          Low Fat         0.315555
# 3              FDQ58     7.315000          Low Fat         0.124050
# 4              FDY38    12.695633          Regular         0.344383
# ...              ...          ...              ...              ...
# 5676           FDB58    10.500000          Regular         0.116174
# 5677           FDD47     7.600000          Regular         0.378141
# 5678           NCO17    10.000000          Low Fat         0.271162
# 5679           FDJ26    15.300000          Regular         0.000000
# 5680           FDU37     9.500000          Regular         0.323605
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      0.000500      Medium               Tier 1
# 1                      0.000498      Medium               Tier 2
# 2                      0.000501      Medium               Tier 3
# 3                      0.000498      Medium               Tier 2
# 4                      0.000504      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                   0.000501       Small               Tier 1
# 5677                   0.000498      Medium               Tier 3
# 5678                   0.000500      Medium               Tier 2
# 5679                   0.000498      Medium               Tier 2
# 5680                   0.000500      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
#Correlation

corr = df[num].corr()
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.018171  0.045257
# Item_Visibility              -0.018171         1.000000 -0.007089
# Item_MRP                      0.045257        -0.007089  1.000000
# Outlet_Establishment_Year    -0.013552         0.070781  0.007254
#
#                            Outlet_Establishment_Year
# Item_Weight                                -0.013552
# Item_Visibility                             0.070781
# Item_MRP                                    0.007254
# Outlet_Establishment_Year                   1.000000

# %%
sns.heatmap(corr,annot = True)
plt.show()

# %%
#scatter plots

plt.scatter(df["Item_MRP"],df["Item_Type"])
plt.xlabel("Item MRP")
plt.ylabel("Item Outlet Sales")
plt.show()

# %%
num
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')

# %%
# # data standardization

# from sklearn.preprocessing import MinMaxScaler

# # Sample data
# data = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# # Initialize MinMaxScaler
# scaler = MinMaxScaler()

# # Fit the scaler to the data and transform the data
# scaled_data = scaler.fit_transform(data)

# print("Original data:")
# print(data)
# print("\nScaled data:")
# print(scaled_data)

# %%
# Z-score normalization, also known as standardization,
# is another common technique used for feature scaling. 
# It rescales features to have a mean of 0 and a standard deviation of 1. 
# This transformation is useful when your data has outliers or does not follow a Gaussian distribution. 
# Here's how you can use z-score normalization in Python with scikit-learn:


# from sklearn.preprocessing import StandardScaler

# # Sample data
# data = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# # Initialize StandardScaler
# scaler = StandardScaler()

# # Fit the scaler to the data and transform the data
# scaled_data = scaler.fit_transform(data)

# print("Original data:")
# print(data)
# print("\nScaled data (Z-scores):")
# print(scaled_data)

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58    20.750000          Low Fat         0.086976
# 1              FDW14     8.300000              reg         0.196030
# 2              NCN55    14.600000          Low Fat         0.315555
# 3              FDQ58     7.315000          Low Fat         0.124050
# 4              FDY38    12.695633          Regular         0.344383
# ...              ...          ...              ...              ...
# 5676           FDB58    10.500000          Regular         0.116174
# 5677           FDD47     7.600000          Regular         0.378141
# 5678           NCO17    10.000000          Low Fat         0.271162
# 5679           FDJ26    15.300000          Regular         0.000000
# 5680           FDU37     9.500000          Regular         0.323605
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      0.000500      Medium               Tier 1
# 1                      0.000498      Medium               Tier 2
# 2                      0.000501      Medium               Tier 3
# 3                      0.000498      Medium               Tier 2
# 4                      0.000504      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                   0.000501       Small               Tier 1
# 5677                   0.000498      Medium               Tier 3
# 5678                   0.000500      Medium               Tier 2
# 5679                   0.000498      Medium               Tier 2
# 5680                   0.000500      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
cat1 = df[["Item_Identifier","Outlet_Identifier"]]

# %%
df.drop(["Item_Identifier","Outlet_Identifier"],axis = 1)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0       20.750000          Low Fat         0.086976         Snack Foods
# 1        8.300000              reg         0.196030               Dairy
# 2       14.600000          Low Fat         0.315555              Others
# 3        7.315000          Low Fat         0.124050         Snack Foods
# 4       12.695633          Regular         0.344383               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.116174         Snack Foods
# 5677     7.600000          Regular         0.378141       Starchy Foods
# 5678    10.000000          Low Fat         0.271162  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.323605              Canned
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0     107.8622                   0.000500      Medium               Tier 1
# 1      87.3198                   0.000498      Medium               Tier 2
# 2     241.7538                   0.000501      Medium               Tier 3
# 3     155.0340                   0.000498      Medium               Tier 2
# 4     234.2300                   0.000504      Medium               Tier 3
# ...        ...                        ...         ...                  ...
# 5676  141.3154                   0.000501       Small               Tier 1
# 5677  169.1448                   0.000498      Medium               Tier 3
# 5678  118.7440                   0.000500      Medium               Tier 2
# 5679  214.6218                   0.000498      Medium               Tier 2
# 5680   79.7960                   0.000500      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 9 columns]

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58    20.750000          Low Fat         0.086976
# 1              FDW14     8.300000              reg         0.196030
# 2              NCN55    14.600000          Low Fat         0.315555
# 3              FDQ58     7.315000          Low Fat         0.124050
# 4              FDY38    12.695633          Regular         0.344383
# ...              ...          ...              ...              ...
# 5676           FDB58    10.500000          Regular         0.116174
# 5677           FDD47     7.600000          Regular         0.378141
# 5678           NCO17    10.000000          Low Fat         0.271162
# 5679           FDJ26    15.300000          Regular         0.000000
# 5680           FDU37     9.500000          Regular         0.323605
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      0.000500      Medium               Tier 1
# 1                      0.000498      Medium               Tier 2
# 2                      0.000501      Medium               Tier 3
# 3                      0.000498      Medium               Tier 2
# 4                      0.000504      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                   0.000501       Small               Tier 1
# 5677                   0.000498      Medium               Tier 3
# 5678                   0.000500      Medium               Tier 2
# 5679                   0.000498      Medium               Tier 2
# 5680                   0.000500      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
cat ,num
# Out:
# (Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#         'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#        dtype='object'),
#  Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#         'Outlet_Establishment_Year'],
#        dtype='object'))

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in df:
    df[i] = LE.fit_transform(df[i])

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                1103          404                 1               66
# 1                1067          223                 4             1714
# 2                1406          338                 1             4042
# 3                 809          156                 1              388
# 4                1184          319                 2             4423
# ...               ...          ...               ...              ...
# 5676              231          293                 2              290
# 5677              306          178                 2             4815
# 5678             1412          288                 1             3256
# 5679              517          349                 2                0
# 5680              987          283                 2             4164
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0            13      1460                  9                          4
# 1             4       965                  2                          1
# 2            11      4076                  0                          5
# 3            13      2522                  2                          1
# 4             4      3972                  5                          8
# ...         ...       ...                ...                        ...
# 5676         13      2164                  8                          6
# 5677         15      2833                  3                          0
# 5678          8      1752                  7                          3
# 5679          3      3691                  2                          1
# 5680          3       806                  7                          3
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# 1               1                     1            1
# 2               1                     2            0
# 3               1                     1            1
# 4               1                     2            3
# ...           ...                   ...          ...
# 5676            2                     0            1
# 5677            1                     2            2
# 5678            1                     1            1
# 5679            1                     1            1
# 5680            1                     1            1
#
# [5681 rows x 11 columns]

# %%
import pickle
#file = "C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Analytics VidhyaBig Mart Sales Prediction\\Big_Mart_Sales_RFtree.pkl"
RFtree= pickle.load(open("C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Analytics Vidhya\\Big Mart Sales Prediction\\Big_Mart_Sales_RFtree.pkl","rb"))
RFtree
# Out:
# RandomForestRegressor()

# %%
y_pred = RFtree.predict(df)
y_pred
# Out:
# array([57.18222816, 56.55446483, 22.98352278, ..., 56.41090495,
#        61.34363769, 56.87711687])

# %%
pred_dt = pd.DataFrame(y_pred,columns= ["Item_Outlet_Sales"])
pred_dt
# Out:
#       Item_Outlet_Sales
# 0             57.182228
# 1             56.554465
# 2             22.983523
# 3             55.233548
# 4             49.154067
# ...                 ...
# 5676          55.854855
# 5677          63.871593
# 5678          56.410905
# 5679          61.343638
# 5680          56.877117
#
# [5681 rows x 1 columns]

# %%
a = pd.concat([cat1,pred_dt],axis=1)
a
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049          57.182228
# 1              FDW14            OUT017          56.554465
# 2              NCN55            OUT010          22.983523
# 3              FDQ58            OUT017          55.233548
# 4              FDY38            OUT027          49.154067
# ...              ...               ...                ...
# 5676           FDB58            OUT046          55.854855
# 5677           FDD47            OUT018          63.871593
# 5678           NCO17            OUT045          56.410905
# 5679           FDJ26            OUT017          61.343638
# 5680           FDU37            OUT045          56.877117
#
# [5681 rows x 3 columns]

# %%
a.set_index("Item_Identifier")
# Out:
#                 Outlet_Identifier  Item_Outlet_Sales
# Item_Identifier
# FDW58                      OUT049          57.182228
# FDW14                      OUT017          56.554465
# NCN55                      OUT010          22.983523
# FDQ58                      OUT017          55.233548
# FDY38                      OUT027          49.154067
# ...                           ...                ...
# FDB58                      OUT046          55.854855
# FDD47                      OUT018          63.871593
# NCO17                      OUT045          56.410905
# FDJ26                      OUT017          61.343638
# FDU37                      OUT045          56.877117
#
# [5681 rows x 2 columns]

# %%
a.reset_index(drop=True)
a=a.set_index("Item_Identifier")
a
# Out:
#                 Outlet_Identifier  Item_Outlet_Sales
# Item_Identifier
# FDW58                      OUT049          57.182228
# FDW14                      OUT017          56.554465
# NCN55                      OUT010          22.983523
# FDQ58                      OUT017          55.233548
# FDY38                      OUT027          49.154067
# ...                           ...                ...
# FDB58                      OUT046          55.854855
# FDD47                      OUT018          63.871593
# NCO17                      OUT045          56.410905
# FDJ26                      OUT017          61.343638
# FDU37                      OUT045          56.877117
#
# [5681 rows x 2 columns]

# %%
a
# Out:
#                 Outlet_Identifier  Item_Outlet_Sales
# Item_Identifier
# FDW58                      OUT049          57.182228
# FDW14                      OUT017          56.554465
# NCN55                      OUT010          22.983523
# FDQ58                      OUT017          55.233548
# FDY38                      OUT027          49.154067
# ...                           ...                ...
# FDB58                      OUT046          55.854855
# FDD47                      OUT018          63.871593
# NCO17                      OUT045          56.410905
# FDJ26                      OUT017          61.343638
# FDU37                      OUT045          56.877117
#
# [5681 rows x 2 columns]

# %%
a.to_csv("Big_Mart_Sales_Result.csv")
