# %%
import numpy as np
import pandas as pd
import seaborn as sns 
sns.set_theme(style='whitegrid', palette='viridis')
import matplotlib.pyplot as plt
import plotly.express as px
import warnings 
warnings.filterwarnings("ignore")

# %%
file_path = "C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Analytics Vidhya\\Black Friday Sales\\test dataset.csv"
df= pd.read_csv(file_path)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3
# 0                     11.0                 NaN
# 1                      5.0                 NaN
# 2                     14.0                 NaN
# 3                      9.0                 NaN
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                 NaN                 NaN
# 233595                 8.0                 NaN
# 233596                 5.0                12.0
# 233597                16.0                 NaN
# 233598                 5.0                 NaN
#
# [233599 rows x 11 columns]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
#pd.set_option("display.max_rows",None)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
df.take([1,3,5])
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1  1000009  P00113442      M  26-35          17             C
# 3  1000010  P00145342      F  36-45           1             B
# 5  1000013  P00350442      M  46-50           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                          0               0                   3
# 3                         4+               1                   4
# 5                          3               1                   2
#
#    Product_Category_2  Product_Category_3
# 1                 5.0                 NaN
# 3                 9.0                 NaN
# 5                 3.0                15.0

# %%
df.take([0,2,5],axis =1)
# Out:
#         User_ID Gender City_Category
# 0       1000004      M             B
# 1       1000009      M             C
# 2       1000010      F             B
# 3       1000010      F             B
# 4       1000011      F             C
# ...         ...    ...           ...
# 233594  1006036      F             B
# 233595  1006036      F             B
# 233596  1006036      F             B
# 233597  1006037      F             C
# 233598  1006039      F             B
#
# [233599 rows x 3 columns]

# %%
df.take([1,4,8],axis = 1).take([100,200,300])
# Out:
#     Product_ID  Occupation  Product_Category_1
# 100  P00175842           7                   5
# 200  P00125642           7                   5
# 300  P00136142           0                   6

# %%
df.iloc[:10,5:]
# Out:
#   City_Category Stay_In_Current_City_Years  Marital_Status  \
# 0             B                          2               1
# 1             C                          0               0
# 2             B                         4+               1
# 3             B                         4+               1
# 4             C                          1               0
# 5             C                          3               1
# 6             C                          3               1
# 7             C                          3               1
# 8             A                          1               0
# 9             A                         4+               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3
# 0                   1                11.0                 NaN
# 1                   3                 5.0                 NaN
# 2                   5                14.0                 NaN
# 3                   4                 9.0                 NaN
# 4                   4                 5.0                12.0
# 5                   2                 3.0                15.0
# 6                   1                11.0                15.0
# 7                   2                 4.0                 9.0
# 8                  10                13.0                16.0
# 9                   5                14.0                 NaN

# %%
df.loc[2:12,["City_Category","Marital_Status"]]
# Out:
#    City_Category  Marital_Status
# 2              B               1
# 3              B               1
# 4              C               0
# 5              C               1
# 6              C               1
# 7              C               1
# 8              A               0
# 9              A               0
# 10             B               1
# 11             B               1
# 12             B               1

# %%
df.shape
# Out:
# (233599, 11)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
(173638/550068)*100
# Out:
# 31.56664266963357

# %%
ID = df[["User_ID","Product_ID"]]

# %%
df.drop(["User_ID","Product_ID","Age","Product_Category_3"],axis = 1,inplace = True)

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           M           7             B                          2
# 1           M          17             C                          0
# 2           F           1             B                         4+
# 3           F           1             B                         4+
# 4           F           1             C                          1
# ...       ...         ...           ...                        ...
# 233594      F          15             B                         4+
# 233595      F          15             B                         4+
# 233596      F          15             B                         4+
# 233597      F           1             C                         4+
# 233598      F           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2
# 0                    1                   1                11.0
# 1                    0                   3                 5.0
# 2                    1                   5                14.0
# 3                    1                   4                 9.0
# 4                    0                   4                 5.0
# ...                ...                 ...                 ...
# 233594               1                   8                 NaN
# 233595               1                   5                 8.0
# 233596               1                   1                 5.0
# 233597               0                  10                16.0
# 233598               1                   4                 5.0
#
# [233599 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Occupation                        0
# City_Category                     0
# Stay_In_Current_City_Years        0
# Marital_Status                    0
# Product_Category_1                0
# Product_Category_2            72344
# dtype: int64

# %%
df["Stay_In_Current_City_Years"] = df["Stay_In_Current_City_Years"].replace("4+","5")

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           M           7             B                          2
# 1           M          17             C                          0
# 2           F           1             B                          5
# 3           F           1             B                          5
# 4           F           1             C                          1
# ...       ...         ...           ...                        ...
# 233594      F          15             B                          5
# 233595      F          15             B                          5
# 233596      F          15             B                          5
# 233597      F           1             C                          5
# 233598      F           0             B                          5
#
#         Marital_Status  Product_Category_1  Product_Category_2
# 0                    1                   1                11.0
# 1                    0                   3                 5.0
# 2                    1                   5                14.0
# 3                    1                   4                 9.0
# 4                    0                   4                 5.0
# ...                ...                 ...                 ...
# 233594               1                   8                 NaN
# 233595               1                   5                 8.0
# 233596               1                   1                 5.0
# 233597               0                  10                16.0
# 233598               1                   4                 5.0
#
# [233599 rows x 7 columns]

# %%
num = []
cat = []
data = df.dtypes
dict1 = dict(data)

for i in dict1:
    if i == "O":
        cat.append(i)
    else:
        num.append(i)
print(f"cat : {cat}")
print(f"num : {num}")
# Out:
# cat : []
# num : ['Gender', 'Occupation', 'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1', 'Product_Category_2']

# %%
cat1 = df.select_dtypes(include = "object").columns
cat1
# Out:
# Index(['Gender', 'City_Category', 'Stay_In_Current_City_Years'], dtype='object')

# %%
num1 = df.select_dtypes(include = ["int64","float64"]).columns
cat1 = df.select_dtypes(include = "object").columns

# %%
num1
# Out:
# Index(['Occupation', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2'],
#       dtype='object')

# %%
cat1
# Out:
# Index(['Gender', 'City_Category', 'Stay_In_Current_City_Years'], dtype='object')

# %%
for i in df:
    a = df[i].unique()
    print(i,a)
# Out:
# Gender ['M' 'F']
# Occupation [ 7 17  1 15  3  0  8 16  4 12 13 18 11  9  2 20 14 10  6 19  5]
# City_Category ['B' 'C' 'A']
# Stay_In_Current_City_Years ['2' '0' '5' '1' '3']
# Marital_Status [1 0]
# Product_Category_1 [ 1  3  5  4  2 10 15 18  8 13  6 11 12  7 16 14 17  9]
# Product_Category_2 [11.  5. 14.  9.  3.  4. 13.  2. nan  8. 15. 17. 12. 16.  6. 10. 18.  7.]

# %%
for i in df:
    a = df[i].nunique()
    print(i,a)
# Out:
# Gender 2
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Product_Category_2 17

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Occupation                        0
# City_Category                     0
# Stay_In_Current_City_Years        0
# Marital_Status                    0
# Product_Category_1                0
# Product_Category_2            72344
# dtype: int64

# %%
df["Product_Category_2"] = df["Product_Category_2"].fillna(df["Product_Category_2"].mean())

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 194772

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           M           7             B                          2
# 1           M          17             C                          0
# 2           F           1             B                          5
# 3           F           1             B                          5
# 4           F           1             C                          1
# ...       ...         ...           ...                        ...
# 233541      M          13             B                          0
# 233544      M          11             A                          2
# 233569      F           0             B                          1
# 233581      M           1             C                          3
# 233597      F           1             C                          5
#
#         Marital_Status  Product_Category_1  Product_Category_2
# 0                    1                   1           11.000000
# 1                    0                   3            5.000000
# 2                    1                   5           14.000000
# 3                    1                   4            9.000000
# 4                    0                   4            5.000000
# ...                ...                 ...                 ...
# 233541               0                   2           17.000000
# 233544               1                  15            9.849586
# 233569               1                   9           15.000000
# 233581               0                  15           17.000000
# 233597               0                  10           16.000000
#
# [38827 rows x 7 columns]

# %%
plt.figure(figsize = (10,10))
for i,column in enumerate(cat1):
    plt.subplot(2,2,i+1)
    ax=sns.countplot(data =df,x=column)
    ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(cat1):
    plt.subplot(2,2,i+1)
    df[column].value_counts().plot(kind="bar")
    plt.xlabel("Class")
    plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(cat1):
    plt.subplot(2,2,i+1)
    plt.title(column)
    n = df[column].nunique()
    l = [0.1 for i in range(n)]
    df[column].value_counts().plot(kind="pie",autopct = "%0.2f%%",startangle = 90,shadow = True,explode = l)
plt.show()

# %%
for i,column in enumerate(cat1):
    plt.figure(figsize = (8,10))
    plt.subplot(2,2,1)
    plt.title(column)
    df[column].value_counts().plot(kind="bar")
    
    plt.subplot(2,2,2)
    plt.title(column)
    n = df[column].nunique()
    l = [0.1 for i in range(n)]
    df[column].value_counts().plot(kind="pie",autopct = "%0.2f%%",shadow = True,startangle = 90,explode = l)
    plt.show()

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           M           7             B                          2
# 1           M          17             C                          0
# 2           F           1             B                          5
# 3           F           1             B                          5
# 4           F           1             C                          1
# ...       ...         ...           ...                        ...
# 233541      M          13             B                          0
# 233544      M          11             A                          2
# 233569      F           0             B                          1
# 233581      M           1             C                          3
# 233597      F           1             C                          5
#
#         Marital_Status  Product_Category_1  Product_Category_2
# 0                    1                   1           11.000000
# 1                    0                   3            5.000000
# 2                    1                   5           14.000000
# 3                    1                   4            9.000000
# 4                    0                   4            5.000000
# ...                ...                 ...                 ...
# 233541               0                   2           17.000000
# 233544               1                  15            9.849586
# 233569               1                   9           15.000000
# 233581               0                  15           17.000000
# 233597               0                  10           16.000000
#
# [38827 rows x 7 columns]

# %%
num1
# Out:
# Index(['Occupation', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2
# count  38827.000000    38827.000000        38827.000000        38827.000000
# mean       8.870374        0.455353            6.077832           11.079064
# std        6.522997        0.498009            4.376827            4.185506
# min        0.000000        0.000000            1.000000            2.000000
# 25%        3.000000        0.000000            2.000000            8.000000
# 50%        7.000000        0.000000            5.000000           11.000000
# 75%       15.000000        1.000000            8.000000           15.000000
# max       20.000000        1.000000           18.000000           18.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38827 entries, 0 to 233597
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gender                      38827 non-null  object
#  1   Occupation                  38827 non-null  int64
#  2   City_Category               38827 non-null  object
#  3   Stay_In_Current_City_Years  38827 non-null  object
#  4   Marital_Status              38827 non-null  int64
#  5   Product_Category_1          38827 non-null  int64
#  6   Product_Category_2          38827 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.4+ MB

# %%
from scipy.stats import skew

# %%
for i in num1:
    a= df[i].skew()
    print(i,a)
# Out:
# Occupation 0.21923305202557067
# Marital_Status 0.17931024635723425
# Product_Category_1 0.7251461935597354
# Product_Category_2 -0.2944320343119802

# %%
df["Product_Category_1"] = np.sqrt(df["Product_Category_1"])

# %%
for i in num1:
    a= df[i].skew()
    print(i,a)
# Out:
# Occupation 0.21923305202557067
# Marital_Status 0.17931024635723425
# Product_Category_1 0.11904253391585747
# Product_Category_2 -0.2944320343119802

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins = 40)
plt.show()

# %%
plt.figure(figsize = (8,10))
for i ,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.distplot(df[column],bins=40)
plt.show()

# %%
for i in num1:
    a= df[i].skew()
    print(i,a)
# Out:
# Occupation 0.21923305202557067
# Marital_Status 0.17931024635723425
# Product_Category_1 0.11904253391585747
# Product_Category_2 -0.2944320343119802

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.boxplot(df[column])
plt.show()

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.boxplot(df[column])
plt.show()

# %%
cat1
# Out:
# Index(['Gender', 'City_Category', 'Stay_In_Current_City_Years'], dtype='object')

# %%
col1 = df["Gender"]
col2 = df["City_Category"]
result1 = pd.crosstab(col1,col2)
result1
# Out:
# City_Category     A     B     C
# Gender
# F              3439  5088  4760
# M              7250  9538  8752

# %%
result1.plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
col1 = df["Gender"]
col2 = df["City_Category"]
col3 = df["Stay_In_Current_City_Years"]

result2 = pd.crosstab([col1,col2],col3)
result2
# Out:
# Stay_In_Current_City_Years     0     1     2     3     5
# Gender City_Category
# F      A                     535  1093   611   726   474
#        B                     652  1569   971  1050   846
#        C                     683  1455  1052   787   783
# M      A                    1348  1891  1440  1310  1261
#        B                    1576  2544  1814  1847  1757
#        C                    1492  2196  1767  1690  1607

# %%
result2.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender,City_Category'>

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                     Occupation  Marital_Status  Product_Category_1  \
# Occupation            1.000000        0.005263           -0.008107
# Marital_Status        0.005263        1.000000            0.005606
# Product_Category_1   -0.008107        0.005606            1.000000
# Product_Category_2   -0.007184        0.006647            0.347165
#
#                     Product_Category_2
# Occupation                   -0.007184
# Marital_Status                0.006647
# Product_Category_1            0.347165
# Product_Category_2            1.000000

# %%
sns.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in cat1:
    df[i] = LE.fit_transform(df[i])

# %%
df
# Out:
#         Gender  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            1           7              1                           2
# 1            1          17              2                           0
# 2            0           1              1                           4
# 3            0           1              1                           4
# 4            0           1              2                           1
# ...        ...         ...            ...                         ...
# 233541       1          13              1                           0
# 233544       1          11              0                           2
# 233569       0           0              1                           1
# 233581       1           1              2                           3
# 233597       0           1              2                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2
# 0                    1            1.000000           11.000000
# 1                    0            1.732051            5.000000
# 2                    1            2.236068           14.000000
# 3                    1            2.000000            9.000000
# 4                    0            2.000000            5.000000
# ...                ...                 ...                 ...
# 233541               0            1.414214           17.000000
# 233544               1            3.872983            9.849586
# 233569               1            3.000000           15.000000
# 233581               0            3.872983           17.000000
# 233597               0            3.162278           16.000000
#
# [38827 rows x 7 columns]

# %%
# from scipy import stats

# columns = ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area']

# zscore = np.abs(stats.zscore(X_train[columns]))

# threshold = 3

# outlier_indices = np.where(zscore > threshold)[0]

# X_train = X_train.drop(X_train.index[outlier_indices])
# y_train = y_train.drop(y_train.index[outlier_indices])

# %%
import pickle

# %%
RF = pickle.load(open("Best_model.pkl2","rb"))
RF
# Out:
# RandomForestRegressor()

# %%
y_pred = RF.predict(df)
y_pred
# Out:
# array([113.70525489, 110.7222923 ,  78.62967168, ..., 119.39611744,
#        129.97403419, 146.48654307])

# %%
pred_RF = pd.DataFrame(y_pred,columns=["Purchase"])
pred_RF
# Out:
#          Purchase
# 0      113.705255
# 1      110.722292
# 2       78.629672
# 3       51.015780
# 4       46.917069
# ...           ...
# 38822  110.390554
# 38823  134.836360
# 38824  119.396117
# 38825  129.974034
# 38826  146.486543
#
# [38827 rows x 1 columns]

# %%
a = pd.concat([pred_RF,ID],axis=1)
a
# Out:
#           Purchase  User_ID Product_ID
# 0       113.705255  1000004  P00128942
# 1       110.722292  1000009  P00113442
# 2        78.629672  1000010  P00288442
# 3        51.015780  1000010  P00145342
# 4        46.917069  1000011  P00053842
# ...            ...      ...        ...
# 233594         NaN  1006036  P00118942
# 233595         NaN  1006036  P00254642
# 233596         NaN  1006036  P00031842
# 233597         NaN  1006037  P00124742
# 233598         NaN  1006039  P00316642
#
# [233599 rows x 3 columns]

# %%
a.reset_index(drop =True)
a=a.set_index("Purchase")
a
# Out:
#             User_ID Product_ID
# Purchase
# 113.705255  1000004  P00128942
# 110.722292  1000009  P00113442
# 78.629672   1000010  P00288442
# 51.015780   1000010  P00145342
# 46.917069   1000011  P00053842
# ...             ...        ...
# NaN         1006036  P00118942
# NaN         1006036  P00254642
# NaN         1006036  P00031842
# NaN         1006037  P00124742
# NaN         1006039  P00316642
#
# [233599 rows x 2 columns]

# %%
a.to_csv('Black Friday Sales Predictions2.csv')
