# %%
import numpy as np
import pandas as pd
import seaborn as sns 
sns.set_theme(style='whitegrid', palette='viridis')
import matplotlib.pyplot as plt
import plotly.express as px
import warnings 
warnings.filterwarnings("ignore")

# %%
file_path = "C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Analytics Vidhya\\Black Friday Sales\\train dataset.csv"
df= pd.read_csv(file_path)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#pd.set_option("display.max_rows",None)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df.take([1,3,5])
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1  1000001  P00248942      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 5  1000003  P00193542      M  26-35          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                          2               0                   1
# 3                          2               0                  12
# 5                          3               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 1                 6.0                14.0     15200
# 3                14.0                 NaN      1057
# 5                 2.0                 NaN     15227

# %%
df.take([0,2,5],axis =1)
# Out:
#         User_ID Gender City_Category
# 0       1000001      F             A
# 1       1000001      F             A
# 2       1000001      F             A
# 3       1000001      F             A
# 4       1000002      M             C
# ...         ...    ...           ...
# 550063  1006033      M             B
# 550064  1006035      F             C
# 550065  1006036      F             B
# 550066  1006038      F             C
# 550067  1006039      F             B
#
# [550068 rows x 3 columns]

# %%
df.take([1,4,8],axis = 1).take([100,200,300])
# Out:
#     Product_ID  Occupation  Product_Category_1
# 100  P00195942          15                   3
# 200  P00115342           3                   5
# 300  P00147942           4                   1

# %%
df.iloc[:10,5:]
# Out:
#   City_Category Stay_In_Current_City_Years  Marital_Status  \
# 0             A                          2               0
# 1             A                          2               0
# 2             A                          2               0
# 3             A                          2               0
# 4             C                         4+               0
# 5             A                          3               0
# 6             B                          2               1
# 7             B                          2               1
# 8             B                          2               1
# 9             A                          1               1
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                   3                 NaN                 NaN      8370
# 1                   1                 6.0                14.0     15200
# 2                  12                 NaN                 NaN      1422
# ...

# %%
df.loc[2:12,["City_Category","Marital_Status"]]
# Out:
#    City_Category  Marital_Status
# 2              A               0
# 3              A               0
# 4              C               0
# 5              A               0
# 6              B               1
# 7              B               1
# 8              B               1
# 9              A               1
# 10             A               1
# 11             A               1
# 12             A               1

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
(173638/550068)*100
# Out:
# 31.56664266963357

# %%
df.drop(["User_ID","Product_ID","Age","Product_Category_3"],axis = 1,inplace = True)

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F          10             A                          2
# 1           F          10             A                          2
# 2           F          10             A                          2
# 3           F          10             A                          2
# 4           M          16             C                         4+
# ...       ...         ...           ...                        ...
# 550063      M          13             B                          1
# 550064      F           1             C                          3
# 550065      F          15             B                         4+
# 550066      F           1             C                          2
# 550067      F           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 0                    0                   3                 NaN      8370
# ...

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Purchase                           0
# dtype: int64

# %%
df["Stay_In_Current_City_Years"] = df["Stay_In_Current_City_Years"].replace("4+","5")

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F          10             A                          2
# 1           F          10             A                          2
# 2           F          10             A                          2
# 3           F          10             A                          2
# 4           M          16             C                          5
# ...       ...         ...           ...                        ...
# 550063      M          13             B                          1
# 550064      F           1             C                          3
# 550065      F          15             B                          5
# 550066      F           1             C                          2
# 550067      F           0             B                          5
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 0                    0                   3                 NaN      8370
# ...

# %%
num = []
cat = []
data = df.dtypes
dict1 = dict(data)

for i in dict1:
    if i == "O":
        cat.append(i)
    else:
        num.append(i)
print(f"cat : {cat}")
print(f"num : {num}")
# Out:
# cat : []
# num : ['Gender', 'Occupation', 'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1', 'Product_Category_2', 'Purchase']

# %%
cat1 = df.select_dtypes(include = "object").columns
cat1
# Out:
# Index(['Gender', 'City_Category', 'Stay_In_Current_City_Years'], dtype='object')

# %%
num1 = df.select_dtypes(include = ["int64","float64"]).columns
cat1 = df.select_dtypes(include = "object").columns

# %%
num1
# Out:
# Index(['Occupation', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Purchase'],
#       dtype='object')

# %%
cat1
# Out:
# Index(['Gender', 'City_Category', 'Stay_In_Current_City_Years'], dtype='object')

# %%
for i in df:
    a = df[i].unique()
    print(i,a)
# Out:
# Gender ['F' 'M']
# Occupation [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# City_Category ['A' 'C' 'B']
# Stay_In_Current_City_Years ['2' '5' '3' '1' '0']
# Marital_Status [0 1]
# Product_Category_1 [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9 20 19]
# Product_Category_2 [nan  6. 14.  2.  8. 15. 16. 11.  5.  3.  4. 12.  9. 10. 17. 13.  7. 18.]
# Purchase [ 8370 15200  1422 ...   135   123   613]

# %%
for i in df:
    a = df[i].nunique()
    print(i,a)
# Out:
# Gender 2
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 20
# Product_Category_2 17
# Purchase 18105

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Purchase                           0
# dtype: int64

# %%
df["Product_Category_2"] = df["Product_Category_2"].fillna(df["Product_Category_2"].mean())

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 11988

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F          10             A                          2
# 1           F          10             A                          2
# 2           F          10             A                          2
# 3           F          10             A                          2
# 4           M          16             C                          5
# ...       ...         ...           ...                        ...
# 550063      M          13             B                          1
# 550064      F           1             C                          3
# 550065      F          15             B                          5
# 550066      F           1             C                          2
# 550067      F           0             B                          5
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 0                    0                   3            9.842329      8370
# ...

# %%
plt.figure(figsize = (10,10))
for i,column in enumerate(cat1):
    plt.subplot(2,2,i+1)
    ax=sns.countplot(data =df,x=column)
    ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(cat1):
    plt.subplot(2,2,i+1)
    df[column].value_counts().plot(kind="bar")
    plt.xlabel("Class")
    plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(cat1):
    plt.subplot(2,2,i+1)
    plt.title(column)
    n = df[column].nunique()
    l = [0.1 for i in range(n)]
    df[column].value_counts().plot(kind="pie",autopct = "%0.2f%%",startangle = 90,shadow = True,explode = l)
plt.show()

# %%
for i,column in enumerate(cat1):
    plt.figure(figsize = (8,10))
    plt.subplot(2,2,1)
    plt.title(column)
    df[column].value_counts().plot(kind="bar")
    
    plt.subplot(2,2,2)
    plt.title(column)
    n = df[column].nunique()
    l = [0.1 for i in range(n)]
    df[column].value_counts().plot(kind="pie",autopct = "%0.2f%%",shadow = True,startangle = 90,explode = l)
    plt.show()

# %%
df
# Out:
#        Gender  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F          10             A                          2
# 1           F          10             A                          2
# 2           F          10             A                          2
# 3           F          10             A                          2
# 4           M          16             C                          5
# ...       ...         ...           ...                        ...
# 550063      M          13             B                          1
# 550064      F           1             C                          3
# 550065      F          15             B                          5
# 550066      F           1             C                          2
# 550067      F           0             B                          5
#
#         Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 0                    0                   3            9.842329      8370
# ...

# %%
num1
# Out:
# Index(['Occupation', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Purchase'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  538080.000000   538080.000000       538080.000000       538080.000000
# mean        8.101972        0.410863            5.391462            9.852082
# std         6.525809        0.491991            3.946981            4.225668
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            8.000000
# 50%         7.000000        0.000000            5.000000            9.842329
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           20.000000           18.000000
#
#             Purchase
# count  538080.000000
# mean     9294.887314
# std      5042.852388
# min        12.000000
# 25%      5824.000000
# 50%      8060.000000
# 75%     12084.000000
# max     23961.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 538080 entries, 0 to 550067
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      538080 non-null  object
#  1   Occupation                  538080 non-null  int64
#  2   City_Category               538080 non-null  object
#  3   Stay_In_Current_City_Years  538080 non-null  object
#  4   Marital_Status              538080 non-null  int64
#  5   Product_Category_1          538080 non-null  int64
#  6   Product_Category_2          538080 non-null  float64
#  7   Purchase                    538080 non-null  int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 36.9+ MB

# %%
from scipy.stats import skew

# %%
for i in num1:
    a= df[i].skew()
    print(i,a)
# Out:
# Occupation 0.3930707607074015
# Marital_Status 0.3623548499685348
# Product_Category_1 1.0243611816485898
# Product_Category_2 -0.1956484902524498
# Purchase 0.5898508404033946

# %%
df["Product_Category_1"] = np.sqrt(df["Product_Category_1"])

# %%
df["Purchase"] = np.sqrt(df["Purchase"])

# %%
for i in num1:
    a= df[i].skew()
    print(i,a)
# Out:
# Occupation 0.3930707607074015
# Marital_Status 0.3623548499685348
# Product_Category_1 0.16208333806721928
# Product_Category_2 -0.1956484902524498
# Purchase -0.13910159470331374

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins = 40)
plt.show()

# %%
plt.figure(figsize = (8,10))
for i ,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.distplot(df[column],bins=40)
plt.show()

# %%
for i in num1:
    a= df[i].skew()
    print(i,a)
# Out:
# Occupation 0.3930707607074015
# Marital_Status 0.3623548499685348
# Product_Category_1 0.16208333806721928
# Product_Category_2 -0.1956484902524498
# Purchase -0.13910159470331374

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.boxplot(df[column])
plt.show()

# %%
q1 = np.quantile(df["Purchase"],.25)
q2 = np.quantile(df["Purchase"],.50)
q3 = np.quantile(df["Purchase"],.75)

Iqr = q3-q1

ub = q3 + (1.5*Iqr)
lb = q1 - (1.5*Iqr)

cond1 = df["Purchase"]>ub
cond2 = df["Purchase"]<lb

outliers = df[cond1|cond2]

# %%
len(outliers)
# Out:
# 5915

# %%
v1 = (len(outliers)/len(df))*100
v1
# Out:
# 1.0992789176330657

# %%
df["Purchase"] = np.clip(df["Purchase"],ub,lb)

# %%
 df[df["Purchase"]>ub]
# Out:
# Empty DataFrame
# Columns: [Gender, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Purchase]
# Index: []

# %%
df[df["Purchase"]<lb]
# Out:
# Empty DataFrame
# Columns: [Gender, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Purchase]
# Index: []

# %%
plt.figure(figsize = (8,10))
for i,column in enumerate(num1):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.boxplot(df[column])
plt.show()

# %%
cat1
# Out:
# Index(['Gender', 'City_Category', 'Stay_In_Current_City_Years'], dtype='object')

# %%
col1 = df["Gender"]
col2 = df["City_Category"]
result1 = pd.crosstab(col1,col2)
result1
# Out:
# City_Category       A       B       C
# Gender
# F               35203   56800   41821
# M              109404  168540  126312

# %%
result1.plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
col1 = df["Gender"]
col2 = df["City_Category"]
col3 = df["Stay_In_Current_City_Years"]

result2 = pd.crosstab([col1,col2],col3)
result2
# Out:
# Stay_In_Current_City_Years      0      1      2      3      5
# Gender City_Category
# F      A                     4967  11945   6757   7367   4167
#        B                     7110  22006   9087  10706   7891
#        C                     4763  16392   8163   6169   6334
# M      A                    18681  36075  19843  17011  17794
#        B                    21116  58609  31736  31068  26011
#        C                    16532  43196  24246  21264  21074

# %%
result2.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender,City_Category'>

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                     Occupation  Marital_Status  Product_Category_1  \
# Occupation            1.000000        0.023048           -0.011168
# Marital_Status        0.023048        1.000000            0.019910
# Product_Category_1   -0.011168        0.019910            1.000000
# Product_Category_2   -0.000600        0.012125            0.401784
# Purchase              0.018867       -0.000736           -0.433509
#
#                     Product_Category_2  Purchase
# Occupation                   -0.000600  0.018867
# Marital_Status                0.012125 -0.000736
# Product_Category_1            0.401784 -0.433509
# Product_Category_2            1.000000 -0.175848
# Purchase                     -0.175848  1.000000

# %%
sns.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in cat1:
    df[i] = LE.fit_transform(df[i])

# %%
df
# Out:
#         Gender  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0          10              0                           2
# 1            0          10              0                           2
# 2            0          10              0                           2
# 3            0          10              0                           2
# 4            1          16              2                           4
# ...        ...         ...            ...                         ...
# 550063       1          13              1                           1
# 550064       0           1              2                           3
# 550065       0          15              1                           4
# 550066       0           1              2                           2
# 550067       0           0              1                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2    Purchase
# ...

# %%
# from scipy import stats

# columns = ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area']

# zscore = np.abs(stats.zscore(X_train[columns]))

# threshold = 3

# outlier_indices = np.where(zscore > threshold)[0]

# X_train = X_train.drop(X_train.index[outlier_indices])
# y_train = y_train.drop(y_train.index[outlier_indices])

# %%
from sklearn.model_selection import train_test_split
x = df.drop("Purchase",axis = 1)
y = df["Purchase"]

# %%
x.shape
# Out:
# (538080, 7)

# %%
y.shape
# Out:
# (538080,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (376656, 7)
# (161424, 7)
# (376656,)
# (161424,)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(x_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [108.50806422 115.71516755  77.04544114  89.12350981  84.17838202]
# [107.03457554  96.62934767  82.78746815  84.54140592  93.11732941]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
mse1 = mean_squared_error(y_test,y_pred)
mae1 = mean_absolute_error(y_test,y_pred)
r2_score1 = r2_score(y_test,y_pred)

# %%
print(f"mse: {mse1}")
print(f"mae : {mae1}")
print(f"r2score : {r2_score1}")
# Out:
# mse: 587.1969877227046
# mae : 18.26145495941864
# r2score : 0.1924565306528725

# %%
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor()
DT.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = DT.predict(x_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [108.50806422 115.71516755  77.04544114  89.12350981  84.17838202]
# [104.79907935 104.05287118  85.46900013  86.23086697  80.50275414]

# %%
mse2 = mean_squared_error(y_test,y_pred)
mae2 = mean_absolute_error(y_test,y_pred)
r2_score2 = r2_score(y_test,y_pred)

# %%
print(f"mse: {mse2}")
print(f"mae : {mae2}")
print(f"r2score : {r2_score2}")
# Out:
# mse: 266.42319655313247
# mae : 12.273030301793765
# r2score : 0.6336011305278204

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN = KNeighborsRegressor()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = KNN.predict(x_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [108.50806422 115.71516755  77.04544114  89.12350981  84.17838202]
# [105.54913789  69.79829146  79.27467348  93.20870845  79.19267351]

# %%
mse3 = mean_squared_error(y_test,y_pred)
mae3 = mean_absolute_error(y_test,y_pred)
r2_score3 = r2_score(y_test,y_pred)

# %%
print(f"mse: {mse3}")
print(f"mae : {mae3}")
print(f"r2score : {r2_score3}")
# Out:
# mse: 362.02876446311114
# mae : 14.17404656608371
# r2score : 0.5021194410553502

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()
RF.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = RF.predict(x_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [108.50806422 115.71516755  77.04544114  89.12350981  84.17838202]
# [101.99436873  95.16330736  85.3410994   86.25559968  80.17220743]

# %%
mse4 = mean_squared_error(y_test,y_pred)
mae4 = mean_absolute_error(y_test,y_pred)
r2_score4 = r2_score(y_test,y_pred)

# %%
print(f"mse: {mse4}")
print(f"mae : {mae4}")
print(f"r2score : {r2_score4}")
# Out:
# mse: 254.79721871249532
# mae : 12.099334991181152
# r2score : 0.6495897726296674

# %%
dict1 = {
    "Mean Square Error" : [mse1,mse2,mse3,mse4],
    "Mean Absolute Error" : [mae1,mae2,mae3,mae4],
    "R2 Score" : [r2_score1,r2_score2,r2_score3,r2_score4]}
pd.DataFrame(dict1,index=["Linear Regression","Decision Tree","KNN","Random Forest"])
# Out:
#                    Mean Square Error  Mean Absolute Error  R2 Score
# Linear Regression         587.196988            18.261455  0.192457
# Decision Tree             266.423197            12.273030  0.633601
# KNN                       362.028764            14.174047  0.502119
# Random Forest             254.797219            12.099335  0.649590

# %%
# random forest has better metrics

# %%
import pickle

# %%
pickle.dump(RF,open("Best_model.pkl","wb"))

# %%
y_predictions = RF.predict(x_test)
y_predictions
# Out:
# array([101.99436873,  95.16330736,  85.3410994 , ...,  83.97342137,
#         90.05773846,  79.3093493 ])
